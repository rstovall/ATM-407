# %% [markdown]
# <a name="top"></a>
#
# <div style="width:1000 px">
#
# <div style="float:right; width:300 px"><img src="https://github.com/brianmapes/ATM407/blob/master/images/Philippe_NAM_80km_3day.vortlesson.png?raw=true" alt="Thermal wind exercise image" style="height: 200px;"></div>
#
#
# <h1>Intensity of storms: vorticity (relative and absolute) and PV</h1>
# <h3>ATM 407, University of Miami</h3>
#
# ### Activities
# 1. <a href="#Exercise1">Recall the 3 kinds of vorticity: relative, absolute, potential</a>
# 1. <a href="#Exercise2">Load bundle, examine basic evolution: vortices coming together</a>
# 1. <a href="#Exercise3">Illustrate storm with an image from the Web</a>
# 1. <a href="#Exercise4">Show PV coming down and converting to absolute vorticity</a>
# 1. <a href="#Exercise5">Show absolute vorticity converting to relative vorticity</a>
# 1. <a href="#Exercise6">Show "diabatic" vortices at low levels, below latent heating</a>
#
# <div style="clear:both"></div>
# </div>
#
# <hr style="height:2px;">
#
# ### Background
# Recall the spirit of the *vorticity equation*: It eliminated the PGF from the horizontal momentum equations:
#
# * Horizontal acceleration equation (F=ma):
# $$ \frac{du}{dt} = - \frac{\partial \Phi}{\partial x} + fv $$
#
# $$ \frac{dv}{dt} = - \frac{\partial \Phi}{\partial y} - fu $$
#
# * Eliminate $\Phi$ by subtracting the y derivative of the u equation from the x derivative of the v equation:
#
# $$ \frac{d}{dt}(\zeta_{abs}) = 0 - \zeta_{abs} (\nabla \cdot V)$$
#
# * Recall that $ \zeta_{abs} = \zeta_{rel} + f $, where f is *planetary vorticity*.
#
# * Divergence changes the ***horizontal area A*** of a mass of a blob of air the same way.
#
# $$ \frac{1}{A} \frac{dA}{dt} = (\nabla \cdot V) $$
#
# $$ \frac{1}{\zeta_{abs}} \frac{d \zeta_{abs}}{dt} = (\nabla \cdot V) $$
#
# * If the air blob's mass is constant, but A increases, then its depth $\delta p$ decreases.
#
# $$ \frac{1}{\delta p} \frac{d\delta p}{dt} = -(\nabla \cdot V) $$
#
# * But what is this "blob" of air? It is bounded by two material surfaces -- **such as $\theta$ surfaces**. So the equation above refers to *the $\delta p$ for a given $\delta \theta$*.
#
# * We can therefore eliminate the divergence term: The ratio stays constant, since convergence *amplifies the numerator* but *decays the denominator* by the same fractional amount.
#
# $$ \frac{d}{dt}(PV) = 0$$
#
# $$ PV = \frac {\zeta_{abs}} {(\delta p / \delta \theta)}$$
#
# (Often people toss in the constant factor of g to turn $\delta p$ (a *weight* of air) into a *mass*.)
#
#
# * Except that $\theta$ isn't quiiite conserved... so we need to write
#
# $$ \frac{d}{dt}(PV) = \zeta_{abs} \frac {\partial}{\partial p}(d\theta/dt) = \zeta_{abs} \frac {\partial}{\partial p}(Q)$$
#
# where Q is our catch-all letter for "diabatic" heating rate (here expressed in $\theta$ units, although that is still K/s or K/d units).
#
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise1"></a>
# <div class="alert alert-success">
#     <b>EXERCISE 1</b>:
#      <ul>
# <li> Fix up the right hand side of the final equation above, by including the factor of g that is customarily used, and writing the right hand side correctly in terms of the latent heating rate (in W/kg units), $ J_{latent} = L dq_v/dt_{cond}. </li>
#
# <li> What is 1 PVU equal to, in MKS units? </li>
#
#     </ul>
# </div>

# %% [markdown]
# ## Exercise 1 Answer
#
# $$ \frac{d}{dt}(PV) = \zeta_{abs} (\frac{\partial}{\partial p}(Q)) = -g(\zeta_{rel} + f)\frac{\partial}{\partial p}(Q) = -g(\zeta_{rel} + f)L\frac{dq_v}{dt} $$
#
# 1 PVU (unit of PV) is equal to $$ \frac{m^2 K}{s kg} $$

# %% [markdown]
# <hr style="height:2px;">
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise2"></a>
# ## Exercise 2: Load the Philippe_NAM_80km_3day.vortlesson IDV bundle and examine the basic evolution
#
# automatically, or manually

# %%
# %reload_ext drilsdown 
# You must do this to activate the IDV-Notebook connection. 
# Then either use the control panel for the automatic approach, or load the IDV bundle manually.
# Out:
# A Jupyter Widget

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE 2</b>:
#      <ul>
#       <li>
#           Describe the basic weather evolution, capturing top-view images or movies that illustrate your description.
#           </li>
#           <li> Use the wind speed and SLP field to show where and when there was an "intense storm". (Note: These data are Saturday's forecast fields -- reality may have come out differently of course!) </li>
#     <li>Find features in the vorticity field that are the essence of that "storm", and describe how they came together. </li>
#     <li> (In the parts below, you will explain where those individual vorticity features came from, more fundamentally.)
#       </li>
#     </ul>
# </div>

# %%
# Your image 
# %makeImage -caption Exercise2
# Out:
# tempfile.tempdir = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'
# tempfile.gettempdir() = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'

# %%
# Your image 
# %makeMovie -caption Exercise2
# Out:
# tempfile.tempdir = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'
# tempfile.gettempdir() = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'

# %% [markdown]
# ## Exercise 2 basic description of situation to be explained:
#
#
# Wind speeds first reach over 60mi/hr on Oct. 29th 18:00:00 UTC just off the coast of North Carolina. This area can also be seen as having low pressure, as demonstrated by the sea level pressure contours encircling the area of highest wind speed. A second low pressure center is visible south of the center containing the high wind speed. From this time, winds continue to intensify and pressure gradients tighten as the pressure centers propogate north on the east coast. Areas of highest wind speed (darker orange above) remain concentrated off the east coast, eventually passing over the Connecticut and Massachusetts area. From here on the highest winds are primarily seen impacting offshore.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise3"></a>
# <div class="alert alert-success">
#     <b>EXERCISE 3</b>:
#      <ul>
#
#       <li>**Find a news or weather image about this weekend's storm in the Northeast. Was the storm well forecast, did it verify? I don't actually know...**
#       </li>
#
#     </ul>
# </div>

# %%
# Image from Web about this storm. 
# Make sure your URL points all the way to an image file, not to a code URL. 
# On any browser image, right-click and select "Open image in new tab", then capture that URL. 

from IPython.display import Image
Image("https://cbsnews3.cbsistatic.com/hub/i/r/2017/10/29/696dccb7-d211-4c26-9f0f-4d4a6821a694/resize/620x/8b0b827e59329953a5ce559a7b354b2a/171029-nhc-5pm-philippe-remnants.jpg")

# %% [markdown]
# ## Answer to exercise 3: the Web image shows...
#
# This article from CBS reports Phillippe leaving the east coast and dissipating into the Atlantic. The eastward movement is backed up by the imagery from the IDV before Oct 29. However the animation from Excercise 2 predicted Phillippe's winds strengthening on and after the 29th, and having greater impacts on the Northeast (i.e. Connecticut). The CBS report also conflicts with the animation in saying wind speeds would never exceed 60mph, as they extended above this threshold beginning on the 29th as mentioned previously.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise4"></a>
# <div class="alert alert-success">
#     <b>EXERCISE 4</b>: Show how PV coming down from the stratosphere made part of the storm's intense vorticity.
#      <ul>
#
# <li>**
#      Examine the potential vorticity field, using the volume rendering and cross section strategically.
#       **</li>
#
# <li>**
#      Find and illustrate (with cross-sections and/or side views of the volume rendering) a place where stratospheric air (with PV values > 1 or 2 PVU) has come down into the tropopshere.
#       **</li>
#
# <li>**
#      Use the theta cross section, the sounding probe, and the absolute vorticity displays (does it increase with time?) to see if the PV remains mostly in the static stability term (as it was in the stratosphere), or got "converted" into actual absolute vorticity.
#       **</li>
#
# <li>**
#      Use the other displays (maybe at middle-upper levels?) to illustrate the most intense circulation you can find that you can attribute to this process of intrusion of high PV from the stratosphere.
#       **</li>
#
#     </ul>
# </div>

# %% [markdown]
# ## Exercise 4 discussion:
#
# Replace this text with your own, perhaps interleaving markdown cells with the images for clarity. **Make the notebook a readable, sensible document: a *weather analysis* **.

# %%
# image 1
# %makeImage -caption Exercise4Image1
# Out:
# tempfile.tempdir = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'
# tempfile.gettempdir() = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'

# %%
# image 2
# %makeMovie -caption Exercise4Animation1
# Out:
# tempfile.tempdir = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'
# tempfile.gettempdir() = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'

# %%
# %makeImage -caption Exercise4Image2
# Out:
# tempfile.tempdir = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'
# tempfile.gettempdir() = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'

# %%
# %makeMovie -caption Exercise4Animation2
# Out:
# tempfile.tempdir = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'
# tempfile.gettempdir() = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'

# %%
# %makeImage -caption Excercise4Image3
# Out:
# tempfile.tempdir = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'
# tempfile.gettempdir() = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'

# %%
# %makeImage

# %%
# Your movies 
#%makeMovie

# %% [markdown]
# ## Exercise 4 discussion:
#
# Image 1 shows purple potential vorticity moving down south of the area of high (>60mph) wind speed previously mentioned as occurring on the 29th at the location indicated in Image 1 by the green line.
# Image 2 shows the downward extending blob of PV moving along the predicted path of Phillippe.
# In Image 3, taken from Oct 31 when high winds from Phillippe were expected to have moved on from the east coast and towards the North Atlantic, no distinct masses of PV appear extending towards the surface as they did in Animation 1.
#
# The second animation is meant to illustrate the conversion of PV (red here) into absolute vorticity (green).
# Image 3 shows an area of high positive relative vorticity (below green line) north of the stratospheric PV.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise5"></a>
# <div class="alert alert-success">
#     <b>EXERCISE 5</b>:
#      <ul>
#
# <li>**
#      Can you find a place where absolute vorticity is converted to relative vorticity?
#       **</li>
#
# <li>**
#     It's a more subtle effect than the Exercise 4 effect, but try anyway, and explain (show the reader you understand) how this happens.
#       **</li>
#
#
#     </ul>
# </div>

# %%
# Your image 
# %makeMovie -caption Exercise5
# Out:
# tempfile.tempdir = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'
# tempfile.gettempdir() = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'

# %%
# Your movies 
#%makeMovie

# %% [markdown]
# ## Exercise 5 answer:
#
# Difficult to tell exactly what the cross section is saying here, since both absolute and relative vorticity are displayed in purple and green.  Positive vorticity (purple) can be seen moving through the cross section.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise6"></a>
# <div class="alert alert-success">
#     <b>EXERCISE 6</b>:
#      <ul>
#
# <li>**
#      Illustrate the 2 patches of relative vorticity offshore that are concentrated at low levels. Where did they come from?
#       **</li>
#
# <li>**
#      Are they PV features? If so, use the PV equation at the top to explain where they came from.
#       **</li>
#
#
#     </ul>
# </div>

# %%
# Your image 
# %makeImage -caption Exercise6
# Out:
# tempfile.tempdir = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'
# tempfile.gettempdir() = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'

# %%
# Your images 
# %makeMovie -caption Animation1
# Out:
# tempfile.tempdir = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'
# tempfile.gettempdir() = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'

# %%
# Your movies 
#%makeMovie

# %% [markdown]
# ## Exercise 6 answer:
#
# The first image shows two patches of intense relative vorticity occurring at the surface, coming from the south and moving along with the pressure centers.
# The animation shows the aforementioned extension of stratospheric PV propogating along the same path as the surface relative vorticity.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# # Illustrating how superposition of vortices makes flow more energetic

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set up a coordinate grid centered on 0,0
n = 10
x,y = np.mgrid[-n:n+1, -n:n+1]


# The flow around a point vortex: decays as 1/r from the central point. 
r = np.sqrt(x**2 + y**2)
theta = np.atan2(x,y)



# Define the display field udisp,vdisp and give it a label. 
# Edit-> Copy and paste this cell, then adjust the top 2 lines for the other cases

udisp,vdisp = 
label = 'Two vortices: KE increases when they are closer together'


# Display the vector field as arrows, CENTERED ON the point they apply to
fig, ax = plt.subplots(figsize=(7,7))
plt.quiver(x, y, udisp, vdisp, pivot='mid')
plt.title(label)
plt.show()
# Out:
#   File "<ipython-input-28-f6926f02b3df>", line 18
#     udisp,vdisp =
#                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">
