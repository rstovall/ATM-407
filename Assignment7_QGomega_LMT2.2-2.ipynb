# %% [markdown]
# <a name="top"></a>
#
# <div style="width:1000 px">
#
# <div style="float:right; width:300 px"><img src="https://github.com/brianmapes/ATM407/blob/master/images/QGlesson.png?raw=true" alt="QG omega eqn exercise image" style="height: 200px;"></div>
#
#
# <h1>QG omega: Exercise 2.2 of Lackmann-Mapes-Tyle manual</h1>
# <h3>ATM 407, University of Miami, fall 2017</h3>
#
# ### Activities
#
# First, show conceptual orientation in question 0. Then,
# 1. <a href="#Exercise1">2.2 Load bundle, show basic evolution</a>
# 1. <a href="#Exercise2">2.2a</a>
# 1. <a href="#Exercise3">2.2b</a>
# 1. <a href="#Exercise4">2.2c</a>
# 1. <a href="#Exercise5">2.2d</a>
# 1. <a href="#Exercise6">2.2e</a>
# 1. <a href="#Exercise7">Pick a historical case</a>
#
# <div style="clear:both"></div>
# </div>
#
# <hr style="height:2px;">
#
# ### Background
#
# The sense of the QG omega equation, if second derivatives are treated like fancy negative signs and coefficients like static stability are treated as constants, is:
#
# ** (Upward motion) = (Vorticity advection increasing w/ height) + (Warm advection) **
#
# Typically, low-level vorticity advection is weak, so that one can simply interpret *upper level (like 500 or 200 hPa) vorticity advection* as an indicator of the first term.
#
#
# Notice that the QG omega equation is a ***diagnostic*** equation, not a **prognostic** equation with a time derivative in it. That is, the right-hand terms do not "lead to" upward motion, they are *equal to it, right now*.
#
# How did this equation come from our governing Primitive Equations set, which has a prognostic form: *d/dt( {winds, and thickness-related T} )  = {PGF&Coriolis, and physical heating rate Q} )*?
#
# The physical concept behind the QG omega equation is, somehow, to state or assume or express the condition that *the flow remains balanced at all times* -- in other words, $\partial (imbalance)/ \partial t$ = 0. That is, the QG "(Upward motion)" in the equation above is *the hypothetical vertical motion field that exactly compensates the balance-destroying tendencies* of the terms on the right-hand side
# .

# %% [markdown]
# <div class="alert alert-success">
#     <b>Question 0: Show your appreciation of background</b>:
#      <ul>
#
#       Refer to your 406 notes or textbook to think about how the omega equation was derived. Use only 2-3 sentences (no math), at the highest conceptual level like the Background above, to answer the following question:
#     <li>
#           ** Broadly (verbally), *How was some measure of the degree of balance or imbalance derived from the u,v,T prognostic equations, in order to express the QG-omega equation's implied physical statement $\partial (imbalance)/ \partial t = 0$?***
#       </li>
#
# </div>

# %% [markdown]
# ## Exercise 0 answer:
#
# The QG Omega equation is dervied by combination of the quasi-geostrophic vorticity and thermodynamic energy equations, both written in terms of geopotential. Combining the equations elimates the time derivites, leaving a diagnostic equation that states vertical motion ($\omega$) is dependent on the relationship between the vertical geostrophic vorticty advection and horizontal temperature advection.
#
# Physically, differences in geostrophic vorticity at the surface and aloft cause geo vorticity advection over systems of high and low pressure, but also require changes in column thickness. In order for these thickness changes to occur, temperature advection must also be present.

# %% [markdown]
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise1"></a>
# ## Load the LMT_2.2 IDV bundle and capture a basic view
#
# load it automatically, or manually

# %%
# %reload_ext drilsdown 

# You must do this to activate the IDV-Notebook connection. 
# Then either use the widget control panel for the automatic launch, or load the IDV bundle manually.
# Out:
# A Jupyter Widget

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE 1</b>:
#      <ul>
#       <li> Read the assignment in the LMT manual, exercise 2.2.
#       </li>
#       <li>
#       ** Capture the initial view, and explain in the caption what it shows. **
#       </li>
#     </ul>
# </div>

# %%
# Your image 
# %makeImage -caption Exercise1
# Out:
# tempfile.tempdir = None
# tempfile.gettempdir() = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'

# %% [markdown]
# ## Exercise 1 caption/answer:
#
# The image shows sea level pressure contours associated with a cyclone at the surface, along with geopotential height contours that show a decreasing thickness to the North.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise2"></a>
# <div class="alert alert-success">
#     <b>EXERCISE 2</b>:
#      <ul>
#
#       <li>
#     2.2 a) i. **Based on the angle between the sea-level isobars and 500-hPa height** contours, ** where do you expect the most pronounced temperature advection at this time? In which areas would the QG omega equation predict forcing for ascent, if we were to base our analysis only
# on this term? Capture and annotate images to illustrate your answers.  **
#       </li>
#
#     </ul>
# </div>

# %%
# Your image 
# %makeImage -caption 2.2ai
# Out:
# tempfile.tempdir = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'
# tempfile.gettempdir() = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'

# %% [markdown]
# ## 2.2 a) i. caption/answer:
#
#
# The most pronounced temperature advection would occur downstream and upstream of the cyclone, where the surface isobars are nearly perpendicular to the geopotential height contours.
# This is part of the second term on the RHS of the QG-omega equation, which depicts horizontal temperature advection. If this term is positive, corresponding to warm air advection, upward vertical motion would be suggested in these areas. A negative term, cold air advection, would denote downward vertical motion in these areas.

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE 2 (contd)</b>:
#      <ul>
#
#       <li>
#     2.2 a) ii. **Activate the QG Temp Adv display. Was your intuition correct? Discuss.** Use the sounding probe to confirm wind veering vs. backing in the warm vs. cold advection areas, as in exercise 1.3.
#       </li>
#
#     </ul>
# </div>

# %%
# Your image 
# %makeImage -caption 2.2aii
# Out:
# tempfile.tempdir = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'
# tempfile.gettempdir() = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'

# %%
from IPython.display import Image
Image("sounding3.jpg")

# %%
from IPython.display import Image
Image("sounding4.jpg")

# %% [markdown]
# ## 2.2 a) ii. caption/answer:
#
# Actual areas of cold and warm advection are near predictions.
# The first sounding, taken from the center of the blue (cold) temperature advection mass shows that winds are turning counterclockwise with height, otherwise known as backing winds.
# The second sounding shows the opposite is true when the probe is placed in the center of the red (warm) temperature advection area. Winds are veering, turning clockwise with height, associated with the warm advection occurring there.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise3"></a>
# <div class="alert alert-success">
#     <b>EXERCISE 3: 2.2 b)</b>:
#      <ul>
#
# <li>** i. Based on the wind and vorticity fields, where do you expect the most prominent areas of cyclonic vorticity advection? Where are these areas in relation to the locations with signficant warm advection?
#
#       **</li>
#
# <li> ii. Activate the Geo Avor Advection display (it is under the QG diagnostics category in the legend). ** Are the regions of cyclonic vorticity advection consistent with what you expected? ** Capture images of the comparison between the two QG advection terms, and discuss them. Since Eq. (2.29) states that the Laplacian of omega equals the forcing terms on the RHS, and inverting the Laplacian acts like a smoothing operation, let’s smooth the forcing term. Click the blue Geo Avor Advection hyperlink in the legend and change the smooth- ing parameter to a factor of 5. Is this a better  t to the scales of true omega (ascent) suggested by the IR satellite imagery? To answer this, toggle the IR satellite display on and off  to see the observed cloud tops field. **Capture images to illustrate your assessment. Discuss what aspects of the IR cloudiness display (convective clouds vs. cirrus decks) might be most related to vertical velocity below the 500-hPa level where the vorticity advection term was evaluated.
#
#
#       **</li>
#
#
#     </ul>
# </div>

# %%
# Your image 
# %makeImage -caption 2.2b
# Out:
# tempfile.tempdir = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'
# tempfile.gettempdir() = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'

# %%
# Your images 
# %makeImage -caption ExerciseN_additional_label
# Out:
# tempfile.tempdir = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'
# tempfile.gettempdir() = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'

# %%
# Your movies 
# %makeImage
# Out:
# tempfile.tempdir = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'
# tempfile.gettempdir() = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'

# %%
# %makeImage
# Out:
# tempfile.tempdir = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'
# tempfile.gettempdir() = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'

# %% [markdown]
# ## 2.2b answer:
#
# i. Cyclonic vorticity advection based on wind and vorticity fields
# The counterclockwise rotation, strongest just North of the center of the low, results in positive vorticity. The purple blob of positive vorticity over this area matches this statement. Postive vorticity advection would then occur downwind (to the east) of this center, which correlates well with the area of warm advection there. The geopotential contours also match, by showing a greater thickness on the eastward side of the center as compared to the west side where the opposite manifestation of physical relationships is occurring.
#
# ii. Geostrophic vorticity advection
# Areas of geostrophic vorticity advection are about where expected, nearly in line with areas of temperature advection. Positive geostrophic vorticity advection is closer to the center of the low pressure system, which makes sense because the difference in geostrophic vorticity between the surfure and aloft above a low is large and positive.
# The highest and most extensive cloud formation is concentrated over the areas of warm air advection and positive geostrpohic vorticity advection, since this is where upward vertical motion would be forced.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise4"></a>
# <div class="alert alert-success">
#     <b>2.2c Vertical pro les at 1200 UTC 18 December 2009</b>:
#      <ul>
#
# <li>** i. Place the skew-T marker in the Map View window over Louisiana. Do you expect QG forcing for ascent or descent in this location at this time? Discuss and justify your answer in terms of the two QG forcing terms.
#
#       **</li>
#
# <li>** ii. Is the midtropospheric dewpoint depression (gap between temperature and dewpoint curves) consistent with the omega implied by the QG forcing terms in (i) over central Louisiana? Discuss.
#
#       **</li>
#
# <li>**
#      iii. Now, move the sounding location to southern Georgia. Do you expect QG forcing for ascent or descent in this location at this time? Discuss and justify your answer in terms of the two QG forcing terms.
#       **</li>
#
# <li>**
# iv. Are the midtropospheric temperature and dewpoint pro les (or the dewpoint depression) consistent with the omega implied by the QG forcing terms over southern Georgia? Discuss.
#
#       **</li>
#
#     </ul>
# </div>

# %%
# Your image 
from IPython.display import Image
Image("sounding1.jpg")

# %%
# Your images 
from IPython.display import Image
Image("sounding2.jpg")

# %% [markdown]
# ## 2.2c answesr:
#
#
# #### i. Winds in this sounding are turning counterclockwise with height (backing) associated with cold air advection over Louisiana. Negative geostrophic vorticity advection is demonstrated here, which can be seen from the wind barbs since they turn more aloft than near the surface. So with height smaller vorticity values are being advected into larger vorticity values.
#
#
# #### ii. The sinking motion implied here would not lead to cloud formation or precipitation, so it makes sense that there is a large gap between temperature and dewpoint since there is no adiabatic cooling within the column forced by vertical motions and no rain is going to be occurring.
#
#
# #### iii. Now winds are turning clockwise with height (veering), signifying warm air advection. Vorticity at the surface appears to be greater than aloft based on turning of the wind barbs with height, which suggests positive vertical vorticity advection.
#
#
# #### iv. The opposite situation is again present here. The rising motion is going to be associated with adiabatic cooling, so temperature and dewpoint will have the same or very nearly the same value in the column. Cloud formation and precipitation will occur, which is also demonstrated by the IR Satellite imagery in the previous exercise.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise5"></a>
# <div class="alert alert-success">
#     <b>d) Analyzed omega</b>:
#      <ul>
#
# <li>See the manual text for background on the question
#
#       </li>
#
# <li>** How well does the analyzed region of ascent match the location of QG forcing for ascent diag- nosed in a) and b)? Does the analyzed omega better match the vorticity advection term or the temperature advection term? Discuss
#
#       **</li>
#
#
#     </ul>
# </div>

# %%
# Your image 
# %makeImage -caption Exercise5
#just omega
# Out:
# tempfile.tempdir = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'
# tempfile.gettempdir() = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'

# %%
# Your images 
# %makeImage -caption vorticity_advection_and_omega
#vorticity advection and omega
# Out:
# tempfile.tempdir = None
# tempfile.gettempdir() = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'

# %%
# Your movies 
# %makeImage -caption temperature_and_omega
# Out:
# tempfile.tempdir = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'
# tempfile.gettempdir() = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'

# %% [markdown]
# ## 2.2d answer:
#
# The areas of ascent and descent predicted previously were accurate. Purple demonstrates negative omega, which corresponds to rising motion. This is present over the areas of warm advection and large, positive geostrophic vorticity advection. The opposite situation is shown by the green (postive) omega, which demonstrates sinking motion and is concentrated over areas of cold advection and negative geostrophic advection.
# In the second and third image, the location of strongest omega, strongest geostrophic vorticity advection and strongest temperature advection can be directly compared. Their respective 'centers' suggest omega better matches the geostrophic vorticity advection term.
# This makes sense if the temperature advection is viewed as a response to the geostrophic vorticity advection, as a means of creating the necessary changes in thickness to maintain thermal and hydrostatic balance.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise6"></a>
# <div class="alert alert-success">
#     <b>e) Infrared satellite imagery</b>:
#      <ul>
#
# <li>**
#      Does the IR satellite imagery display agree qualitatively with the ana- lyzed omega, QG-predicted omega, the individual QG omega forcing terms, and the sounding’s dewpoint depression? Discuss.
#       **</li>
#
#
#     </ul>
# </div>

# %%
# Your image 
# %makeImage -caption Exercise6
# Out:
# tempfile.tempdir = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'
# tempfile.gettempdir() = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'

# %% [markdown]
# ## 2e. answer:
#
# Areas of negative omega (rising motion) clearly match well with areas of more extensive cloud cover, while sinking motion associated with positive vorticity correlate with areas of little to no cloud cover. As mentioned briefly in the discussion of soundings taken over Lousiana and Georgia, the cloud cover matches will veering and backing winds shown in the soundings.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise7"></a>
# <div class="alert alert-success">
#     <b>Exercise 7: A case of your own</b>:
#      <ul>
#
# <li>** Examine the same set of displays for another historical weather situation and discuss the issues above in that context. ** <li> To do this for a historical case in 1979–2015, **load bundle LMT_2.2_MERRA_1979–2015. **
#
# <li> (If your course is in the winter, with good realtime weather, you can use LMT_2.2_RT).
#          </li>
#
# <br>
#
# <li> **While you wait for IDV to load, find the place and time of a historical storm that interests you. Everyone choose a different one please. **
#          </li>
#
#  <br>
#
#     To view another area of the globe in The IDV, zoom out until your desired region is visible, and then hold the Shift key while rubberbanding a latitude–longitude box with the left  mouse button depressed.  Then, to adjust the time(s) you want to see, click the "i" icon in the animation control area and operate the Define Animation Times tab in the popup. **Read menu items carefully to avoid excessively large data requests that will spoil your session.** Unfortunately, the sounding probe will not automatically follow the other displays for IDV versions before 5.3. In that case, you have to zoom out after the data finish loading and move the probe to the area in which your data have been fetched. Once you  find a case you like, consider saving it as a .zidv bundle, and feel free to contact an author of this manual if you wish to share it more broadly.
#
#
#
#     </ul>
# </div>

# %%
# Your image 
# %makeImage -caption Exercise7_temperature_advection
# Out:
# tempfile.tempdir = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'
# tempfile.gettempdir() = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'

# %%
# Your images 
# %makeImage -caption Exercise7_geostrophic_vorticity_advection
# Out:
# tempfile.tempdir = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'
# tempfile.gettempdir() = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'

# %%
# Your movies 
# %makeImage -caption Exercise7_omega
# Out:
# tempfile.tempdir = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'
# tempfile.gettempdir() = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'

# %%
 # %makeImage -caption Exercise7_all_layered
# Out:
# tempfile.tempdir = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'
# tempfile.gettempdir() = '/var/folders/b2/pgfp11kx60b477n04zxs94y40000gn/T'

# %%
from IPython.display import Image
Image("weatherforfl.png")

# %%
from IPython.display import Image
Image("weatherforhouston.png")

# %% [markdown]
# ## Exercise 7 answer:
#
# Similiar relationships as described previously are evident for this low pressure system from Dec 18, 2009. In the first image, warm temperature advection is to the east of the system while cold advection occurs to the west of the system. Positive geostrophic vorticity advection is again distributed in the same way as temperature advection, but with positive advection being geographically closer to the center of the low. Finally, the omega values are displayed. As expected, negative omega (rising motion) is displayed over the warm advection/positive geostrophic vorticity advection and positive omega (sinking motion) is displayed over the cold advection/negative geostrophic vorticity advection.
#
# Weather in Tallahassee on this day in 2009, taken from Weather Underground historical data, shows that rain occurred throughout the morning (and the rest of the day). This makes sense with the rising motion that was occurring over the area near this time.
#
# Comparing this to weather in Houston, TX from the same date and time (also taken from same source) show fair conditions with clear skies. This correlates well with the sinking motion predicted there.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">
